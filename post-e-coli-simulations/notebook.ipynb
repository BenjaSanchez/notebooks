# %% [markdown]
# # Simulations of _E. coli_
#
# This notebook contains simple tests of the E. coli model `iML1515` both in regular and ecModel format.
#
# Benjamín J. Sánchez, 2019-10-15
#
# ## 1. Loading models
#
# * Metabolic model: https://github.com/SysBioChalmers/ecModels/blob/chore/updateiML1515/eciML1515/model/eciML1515.xml
# * ecModel: https://github.com/SysBioChalmers/ecModels/blob/chore/updateiML1515/eciML1515/model/eciML1515.xml
#
# (temporal, eventually they will be available in the master branch)

# %%
import cobra
import os
import wget

# Metabolic model:
wget.download("https://raw.githubusercontent.com/SysBioChalmers/ecModels/chore/updateiML1515/eciML1515/model/iML1515.xml", "iML1515.xml", bar=False)
model = cobra.io.read_sbml_model("iML1515.xml")
os.remove("iML1515.xml")

# Enzyme-constrained model:
os.remove("eciML1515.xml")
wget.download("https://raw.githubusercontent.com/SysBioChalmers/ecModels/chore/updateiML1515/eciML1515/model/eciML1515.xml", "eciML1515.xml", bar=False)
ecModel = cobra.io.read_sbml_model("eciML1515.xml")
os.remove("eciML1515.xml")

# %% [markdown]
# ## 2. Simulating models
#
# ### 2.1. Simulating the metabolic model

# %%
model.objective.expression.args[0]
# Out:
# 1.0*BIOMASS_Ec_iML1515_core_75p37M

# %%
model.solver.timeout = 30
solution = model.optimize()
solution
# Out:
# <Solution 0.877 at 0x13689124048>

# %%
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>22.131763</td>
#       <td>h2o_e</td>
#       <td>47.162365</td>
#       <td>BIOMASS_Ec_iML1515_core_75p37M</td>
#       <td>0.876997</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>glc__D_e</td>
#       <td>10.000000</td>
#       <td>co2_e</td>
#       <td>24.003293</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>nh4_e</td>
#       <td>9.471495</td>
#       <td>h_e</td>
#       <td>8.058200</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.845957</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
for reaction in model.reactions:
    if len(reaction.metabolites) == 1 and solution.fluxes[reaction.id] < 0:
        print(reaction.id + ": " + str(solution.fluxes[reaction.id]))
# Out:
# EX_pi_e: -0.8459567750195813
# EX_mn2_e: -0.0006060050751690353
# EX_fe2_e: -0.01408545226091154
# EX_glc__D_e: -10.0
# EX_zn2_e: -0.000299056050119596
# EX_mg2_e: -0.0076079508351539465
# EX_ca2_e: -0.004564770501092374
# EX_ni2_e: -0.0002832701002599107
# EX_cu2_e: -0.000621791025028721
# EX_cobalt2_e: -2.1924930360674225e-05
# EX_nh4_e: -9.47149537104813
# EX_mobd_e: -6.138980500988783e-06
# EX_so4_e: -0.220845438536999
# EX_k_e: -0.17118371727564335
# EX_o2_e: -22.13176323894588
# EX_cl_e: -0.004564770501092374

# %% [markdown]
# Note that in total 16 metabolites are consumed: oxygen, glucose, ammonia, phosphate, sulphate and 11 minerals.

# %% [markdown]
# ### 2.2. Simulating the enzyme-constrained model _as-is_

# %%
ecModel.objective.expression.args[0]
# Out:
# 1.0*BIOMASS_Ec_iML1515_core_75p37M

# %%
ecModel.solver.timeout = 30
ecModel.optimize()
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-7-49e6c7df00bb> in <module>
#       1 ecModel.solver.timeout = 30
# ----> 2 ecModel.optimize()
#
# c:\users\bejsab\appdata\local\continuum\anaconda3\envs\notebooks\lib\site-packages\cobra\core\model.py in optimize(self, objective_sense, raise_error)
#    1080                 objective_sense, original_direction)
#    1081         self.slim_optimize()
# -> 1082         solution = get_solution(self, raise_error=raise_error)
#    1083         self.objective.direction = original_direction
#    1084         return solution
#
# c:\users\bejsab\appdata\local\continuum\anaconda3\envs\notebooks\lib\site-packages\cobra\core\solution.py in get_solution(model, reactions, metabolites, raise_error)
#     220     legacy solvers.
#     221     """
# --> 222     check_solver_status(model.solver.status, raise_error=raise_error)
#     223     if reactions is None:
#     224         reactions = model.reactions
#
# c:\users\bejsab\appdata\local\continuum\anaconda3\envs\notebooks\lib\site-packages\cobra\util\solver.py in check_solver_status(status, raise_error)
#     419             "model was not optimized yet or solver context switched")
#     420     else:
# --> 421         raise OptimizationError("solver status is '{}'".format(status))
#     422
#     423
#
# OptimizationError: solver status is 'unbounded'

# %% [markdown]
# ### 2.3 Fixing the enzyme-constrained model
#
# cobrapy cannot handle upper bounds = `Inf`, therefore we need to replace them with `1000` (standard in the field):

# %%
import math

for reaction in ecModel.reactions:
    if math.isinf(reaction.upper_bound):
        reaction.upper_bound = 1000

ecModel.optimize()
# Out:
# <Solution 74.896 at 0x13684fcae48>

# %% [markdown]
# Pretty high objective function -> we need to lower the upper bound of glucose uptake:

# %%
ecModel.reactions.EX_glc__D_e_REV.upper_bound = 10
ecModel.optimize()
# Out:
# <Solution 74.896 at 0x13685128348>

# %% [markdown]
# Nothing changed -> let's look at the summary of in/out fluxes:

# %%
ecModel.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>acald_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BIOMASS_Ec_iML1515_core_75p37M</td>
#       <td>74.895747</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>akg_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>fe2_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>glu__L_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>glyc3p_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>indole_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>no3_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>o2s_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>thr__L_e[e]</td>
#       <td>1000.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>tartr__D_e[e]</td>
#       <td>997.115915</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>alltn_e[e]</td>
#       <td>994.514373</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>dha_e[e]</td>
#       <td>992.922277</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>o2_e[e]</td>
#       <td>845.358475</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>chol_e[e]</td>
#       <td>517.573098</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>cu_e[e]</td>
#       <td>382.636800</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>h2_e[e]</td>
#       <td>110.805225</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>galct__D_e[e]</td>
#       <td>108.137907</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>LalaDglu_e[e]</td>
#       <td>39.686358</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>leu__L_e[e]</td>
#       <td>33.742856</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>val__L_e[e]</td>
#       <td>31.693034</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>ins_e[e]</td>
#       <td>28.960463</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>ser__L_e[e]</td>
#       <td>26.607913</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>lys__L_e[e]</td>
#       <td>25.701300</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>arg__L_e[e]</td>
#       <td>22.153563</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>ile__L_e[e]</td>
#       <td>21.759387</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>gsn_e[e]</td>
#       <td>18.216743</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>asn__L_e[e]</td>
#       <td>18.053994</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pro__L_e[e]</td>
#       <td>16.556079</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>ade_e[e]</td>
#       <td>15.320974</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>k_e[e]</td>
#       <td>14.619126</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>phe__L_e[e]</td>
#       <td>13.875561</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>cytd_e[e]</td>
#       <td>12.022640</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>met__L_e[e]</td>
#       <td>11.493726</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>uri_e[e]</td>
#       <td>10.792777</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>tyrp_e[e]</td>
#       <td>10.327824</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We see that there are many uptake fluxes fully unconstrained. Let's fix all of them to zero except for the original 16:

# %%
for reaction in ecModel.reactions:
    if len(reaction.metabolites) == 1 and reaction.name.endswith(" (reversible)"):
        reaction.lower_bound = 0
        reaction.upper_bound = 0

ecModel.reactions.EX_glc__D_e_REV.upper_bound = 10   #glucose will be limiting
ecModel.reactions.EX_pi_e_REV.upper_bound = 1000
ecModel.reactions.EX_mn2_e_REV.upper_bound = 1000
ecModel.reactions.EX_fe2_e_REV.upper_bound = 1000
ecModel.reactions.EX_zn2_e_REV.upper_bound = 1000
ecModel.reactions.EX_mg2_e_REV.upper_bound = 1000
ecModel.reactions.EX_ca2_e_REV.upper_bound = 1000
ecModel.reactions.EX_ni2_e_REV.upper_bound = 1000
ecModel.reactions.EX_cu2_e_REV.upper_bound = 1000
ecModel.reactions.EX_cobalt2_e_REV.upper_bound = 1000
ecModel.reactions.EX_nh4_e_REV.upper_bound = 1000
ecModel.reactions.EX_mobd_e_REV.upper_bound = 1000
ecModel.reactions.EX_so4_e_REV.upper_bound = 1000
ecModel.reactions.EX_k_e_REV.upper_bound = 1000
ecModel.reactions.EX_o2_e_REV.upper_bound = 1000
ecModel.reactions.EX_cl_e_REV.upper_bound = 1000

ecModel.optimize()
# Out:
# <Solution 0.877 at 0x13684fbc2c8>

# %% [markdown]
# Success!!

# %% [markdown]
# ## 3. Correcting model fields:

# %%
# Metabolite ids: remove the trailing "[comp]" (if any):
for metabolite in ecModel.metabolites:
    trail = "[" + metabolite.compartment + "]"
    if metabolite.id.endswith(trail):
        metabolite.id = metabolite.id.split(trail)[0]

# %% [markdown]
# ## 4. Model export

# %%
#Save model as .xml & .json:
cobra.io.write_sbml_model(ecModel, "eciML1515.xml")
cobra.io.save_json_model(ecModel, "eciML1515.json")

# %% [markdown]
# ## 5. Changing GAM

# %%
print(model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M'))
# Out:
# BIOMASS_Ec_iML1515_core_75p37M: 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0.513689 ala__L_c + 0.000223 amet_c + 0.295792 arg__L_c + 0.241055 asn__L_c + 0.241055 asp__L_c + 75.55223 atp_c + 2e-06 btn_c + 0.005205 ca2_c + 0.005205 cl_c + 0.000576 coa_c + 2.5e-05 cobalt2_c + 0.133508 ctp_c + 0.000709 cu2_c + 0.09158 cys__L_c + 0.026166 datp_c + 0.027017 dctp_c + 0.027017 dgtp_c + 0.026166 dttp_c + 0.000223 fad_c + 0.006715 fe2_c + 0.007808 fe3_c + 0.26316 gln__L_c + 0.26316 glu__L_c + 0.612638 gly_c + 0.215096 gtp_c + 70.028756 h2o_c + 0.094738 his__L_c + 0.290529 ile__L_c + 0.195193 k_c + 0.019456 kdo2lipid4_e + 0.450531 leu__L_c + 0.343161 lys__L_c + 0.153686 met__L_c + 0.008675 mg2_c + 0.000223 mlthf_c + 0.000691 mn2_c + 7e-06 mobd_c + 0.013894 murein5px4p_p + 0.001831 nad_c + 0.000447 nadp_c + 0.013013 nh4_c + 0.000323 ni2_c + 0.063814 pe160_p + 0.075214 pe161_p + 0.185265 phe__L_c + 0.000223 pheme_c + 0.221055 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.215792 ser__L_c + 0.000223 sheme_c + 0.004338 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.253687 thr__L_c + 0.056843 trp__L_c + 0.137896 tyr__L_c + 5.5e-05 udcpdp_c + 0.144104 utp_c + 0.423162 val__L_c + 0.000341 zn2_c --> 75.37723 adp_c + 75.37723 h_c + 75.37323 pi_c + 0.773903 ppi_c

# %%
model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M').add_metabolites({model.metabolites.atp_c: -10.0})
model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M').add_metabolites({model.metabolites.h2o_c: -10.0})
model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M').add_metabolites({model.metabolites.adp_c: -10.0})
model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M').add_metabolites({model.metabolites.h_c: -10.0})
model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M').add_metabolites({model.metabolites.pi_c: -10.0})

# %%
print(model.reactions.get_by_id('BIOMASS_Ec_iML1515_core_75p37M'))
# Out:
# BIOMASS_Ec_iML1515_core_75p37M: 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0.513689 ala__L_c + 0.000223 amet_c + 0.295792 arg__L_c + 0.241055 asn__L_c + 0.241055 asp__L_c + 85.55223 atp_c + 2e-06 btn_c + 0.005205 ca2_c + 0.005205 cl_c + 0.000576 coa_c + 2.5e-05 cobalt2_c + 0.133508 ctp_c + 0.000709 cu2_c + 0.09158 cys__L_c + 0.026166 datp_c + 0.027017 dctp_c + 0.027017 dgtp_c + 0.026166 dttp_c + 0.000223 fad_c + 0.006715 fe2_c + 0.007808 fe3_c + 0.26316 gln__L_c + 0.26316 glu__L_c + 0.612638 gly_c + 0.215096 gtp_c + 80.028756 h2o_c + 0.094738 his__L_c + 0.290529 ile__L_c + 0.195193 k_c + 0.019456 kdo2lipid4_e + 0.450531 leu__L_c + 0.343161 lys__L_c + 0.153686 met__L_c + 0.008675 mg2_c + 0.000223 mlthf_c + 0.000691 mn2_c + 7e-06 mobd_c + 0.013894 murein5px4p_p + 0.001831 nad_c + 0.000447 nadp_c + 0.013013 nh4_c + 0.000323 ni2_c + 0.063814 pe160_p + 0.075214 pe161_p + 0.185265 phe__L_c + 0.000223 pheme_c + 0.221055 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.215792 ser__L_c + 0.000223 sheme_c + 0.004338 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.253687 thr__L_c + 0.056843 trp__L_c + 0.137896 tyr__L_c + 5.5e-05 udcpdp_c + 0.144104 utp_c + 0.423162 val__L_c + 0.000341 zn2_c --> 65.37723 adp_c + 65.37723 h_c + 65.37323 pi_c + 0.773903 ppi_c
